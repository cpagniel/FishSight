# %% [markdown]
# # Build Freamework: Cloning and Building Darknet

# %%
# clone darknet 
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15138, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 15138 (delta 29), reused 50 (delta 23), pack-reused 15073
# Receiving objects: 100% (15138/15138), 13.50 MiB | 22.66 MiB/s, done.
# Resolving deltas: 100% (10275/10275), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# /content/darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# make darknet 
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ./src/image_opencv.cpp:1139:10: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#           if (iteration_old != 0){
#           ^~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1433:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1409:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1413:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1417:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1420:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:511:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:867:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ./src/http_stream.cpp:875:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#                           ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:894:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#                          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:930:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#          ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2044:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2043:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1045:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#      while (c = *str++)
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:231:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: In function ‘cublas_check_error_extended’:
# ./src/dark_cuda.c:265:18: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum cudaError_enum’ [-Wenum-compare]
#        if (status != CUDA_SUCCESS)
#                   ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:396:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:396:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:396:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:406:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:427:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:442:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:448:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# At top level:
# ./src/dark_cuda.c:288:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#  static cublasHandle_t switchBlasHandle[16];
#                        ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:287:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#  static int switchBlasInit[16] = { 0 };
#             ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1341:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                           ~^
#                                                           %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                   ~^
#                                                                   %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                           ~^
#                                                                           %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                    ~^
#                                                                    %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                            ~^
#                                                                            %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                                    ~^
#                                                                                    %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:785:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:785:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:203:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#      fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#                                                                                                    ~~^
#                                                                                                    %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:244:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#                      float max_truth = 0;
#                            ^~~~~~~~~
# ./src/softmax_layer.c:423:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#              printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#                                                                       ~^
#                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1297:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1090:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:434:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#          int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#              ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:659:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1719:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1851:9: warning: unused variable ‘i’ [-Wunused-variable]
#      int i;
#          ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:438:29: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#          classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#          ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:0:
# /usr/include/stdlib.h:541:14: note: in a call to allocation function ‘calloc’ declared here
#  extern void *calloc (size_t __nmemb, size_t __size)
#               ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:386:72: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#              (iteration >= (iter_save + 1000) || iteration % 1000 == 0) && net.max_batches < 10000)
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:486:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:579:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:700:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:698:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1332:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1331:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1867:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1287:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1287:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/representation_layer.c -o obj/representation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:101:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:63:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:62:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:68:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:75:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:106:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ...
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:120:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:364:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %% [markdown]
# Using the below helper function to view images

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)

# %% [markdown]
# # Move files: Uploading Google Drive Files

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/Shareddrives/FishOASIS/ /mydrive

# %%
# cd back into the darknet folder to run detections
# %cd ..
# %cd /content/darknet
# Out:
# /
# /content/darknet

# %%
# !ls
# Out:
# darknet  gdrive  sample_data

# %% [markdown]
# # TRAINING:

# %% [markdown]
# In order to create a custom YOLOv4-TINY detector we will need the following:
#
# *   Labeled Dataset
# *   .cfg file
# *   obj.data and obj.names files
# *   train.txt file, test.txt

# %% [markdown]
# # Step 1: Gathering and Labeling a Custom Dataset
# In order to create an object detector you need a labeled dataset, this may be the most important area to focus on in order to obtain high accuracy models

# %% [markdown]
# # Step 2: Moving Your Custom Dataset Into Your Cloud VM
# I recommend renaming the folder with your images and text files on your local machine to be called '**obj**' and then creating a .zip folder of the 'obj' folder.

# %%
# See if train.zip & test.zip is in the folder
# !ls -lh /mydrive/INTERNS/CLARE/YOLO_main/
# Out:
# total 39G
# drwx------ 2 root root 4.0K Jun  4 17:31 backup
# -rw------- 1 root root  524 Jun  4 17:41 generate_namelist.py
# -rw------- 1 root root  132 Jun  4 17:32 obj.data
# -rw------- 1 root root    6 Jun  1 10:05 obj.names
# -rw------- 1 root root 6.8G Jun  4 14:48 test.zip
# -rw------- 1 root root  33G Jun  4 14:12 train.zip
# lrw------- 1 root root   63 May 31 11:51 YOLO_main -> //content/gdrive/Shareddrives/FishOASIS/INTERNS/CLARE/YOLO_main
# -rw------- 1 root root 982K Jun  6 16:56 YoloV4-FishOASIS-Train.ipynb
# -rw------- 1 root root 3.2K Jun  3 07:17 yolov4-tiny.cfg
# -rw------- 1 root root  19M Jun  1 10:05 yolov4-tiny.conv.29

# %%
# copy the .zip files into the root directory of cloud VM
# !cp /mydrive/INTERNS/CLARE/Data/train_b/train.zip ../
# !cp /mydrive/INTERNS/CLARE/Data/train_b/test.zip ../

# %%
# unzip the zip files and its contents should now be in /darknet/data/train & data/test
# !unzip ../train.zip -d data/
# !unzip ../test.zip -d data/

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %% [markdown]
# # Step 3: Configuring Files for Training
# This step involves properly configuring your custom .cfg file, obj.data, obj.names and train.txt file.

# %% [markdown]
# ```
# set batch=24, this means we will be using 24 images for every training step
# set subdivisions=8, the batch will be divided by 8 to decrease GPU VRAM requirement
# width= 608 (multiples of 32)
# height= 608 (increasing: more prescision, less speed)
# maxbatches= max(# classes * 3000, # images, 6000) (How long to train for)
# steps=(80% of maxbatch & 90% of maxbatch)
# filters=(# of classes + 5) * 3 = 18
# for memory issues set random = 0
# ```

# %%
# upload the yolov4-tiny .cfg back to cloud VM from Google Drive
# !cp /mydrive/INTERNS/CLARE/YOLO_main/yolov4-tiny.cfg ./cfg

# %% [markdown]
# Uploading obj.names & obj.data into darknet data folder

# %%
# upload the obj.names and obj.data files to cloud VM from Google Drive
# !cp /mydrive/INTERNS/CLARE/YOLO_main/obj.names ./data
# !cp /mydrive/INTERNS/CLARE/YOLO_main/obj.data  ./data

# %% [markdown]
# Uploading scripts to create a txt file of the train.zip & test.zip

# %%
# upload the generate_train.py script to cloud VM from Google Drive
# !cp /mydrive/INTERNS/CLARE/YOLO_main/generate_namelist.py ./

# %% [markdown]
# Now run the python script

# %%
# !mkdir data/train
# !mkdir data/test
# !mv data/one_train_b data/train/one_train_b
# !mv data/one_valid_b data/test/one_valid_b

# %%
# !python generate_namelist.py train
# !python generate_namelist.py test

# %%
# verify train.txt and text.txt can be seen in our darknet/data folder
# !ls data/
# Out:
# 9k.tree     giraffe.jpg		      labels		scream.jpg  voc.names
# coco9k.map  goal.txt		      obj.data		test
# coco.names  horses.jpg		      obj.names		test.txt
# dog.jpg     imagenet.labels.list      openimages.names	train
# eagle.jpg   imagenet.shortnames.list  person.jpg	train.txt

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %% [markdown]
# # Step 4: Download pre-trained weights for the convolutional layers.
# Using pretrained weights allows a more accurate detection with less training time

# %%
# upload pretrained convolutional layer weights
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights
# !cp /mydrive/INTERNS/CLARE/YOLO_main/yolov4-tiny.conv.29 ./

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       obj
# backup			data		       README.md
# build			generate_namelist.py   results
# build.ps1		image_yolov3.sh        scripts
# cfg			image_yolov4.sh        src
# cmake			include		       vcpkg.json
# CMakeLists.txt		json_mjpeg_streams.sh  video_yolov3.sh
# darknet			LICENSE		       video_yolov4.sh
# DarknetConfig.cmake.in	Makefile	       yolov4-tiny.conv.29
# darknet_images.py	net_cam_v3.sh
# darknet.py		net_cam_v4.sh

# %% [markdown]
# #Hint:

# %% [markdown]
# To avoid colab logging you out hit (CTRL + SHIFT + i) to open consol
#
# Paste the following code into your console window and hit enter
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
# ```

# %% [markdown]
# # Step 5: Train the model

# %%
# cd back into the darknet folder to run detections
# %cd ..
# %cd /content/darknet
# Out:
# /content
# /content/darknet

# %%
# train your yolov4-tiny detector
# %%capture training_output
# !./darknet detector train data/obj.data cfg/yolov4-tiny.cfg yolov4-tiny.conv.29 -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 229072, rewritten_bbox = 0.868722 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000523, iou_loss = 0.000000, total_loss = 0.000523
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.429992), count: 4, class_loss = 1.025635, iou_loss = 9.920821, total_loss = 10.946457
#  total_bbox = 229076, rewritten_bbox = 0.868707 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000072, iou_loss = 0.000000, total_loss = 0.000072
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.613047), count: 39, class_loss = 6.832361, iou_loss = 152.698410, total_loss = 159.530777
#  total_bbox = 229115, rewritten_bbox = 0.869869 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.659646), count: 1, class_loss = 0.313631, iou_loss = 0.292518, total_loss = 0.606149
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.654241), count: 1, class_loss = 0.356421, iou_loss = 0.287508, total_loss = 0.643928
#  total_bbox = 229117, rewritten_bbox = 0.869861 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000008, iou_loss = 0.000000, total_loss = 0.000008
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.504858), count: 3, class_loss = 0.770993, iou_loss = 9.738808, total_loss = 10.509800
#  total_bbox = 229120, rewritten_bbox = 0.869850 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000008, iou_loss = 0.000000, total_loss = 0.000008
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.049016, iou_loss = 0.000000, total_loss = 0.049016
#  total_bbox = 229120, rewritten_bbox = 0.869850 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.520900), count: 1, class_loss = 0.226786, iou_loss = 0.264638, total_loss = 0.491423
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.453663), count: 15, class_loss = 4.507498, iou_loss = 24.496033, total_loss = 29.003531
#  total_bbox = 229136, rewritten_bbox = 0.869789 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000077, iou_loss = 0.000000, total_loss = 0.000077
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.706024), count: 1, class_loss = 0.154428, iou_loss = 4.319168, total_loss = 4.473596
#  total_bbox = 229137, rewritten_bbox = 0.869785 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5833: 1.145110, 0.693716 avg loss, 0.000026 rate, 0.640718 seconds, 139992 images, 0.436683 hours left
# Loaded: 4.060610 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.004966, iou_loss = 0.000000, total_loss = 0.004966
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.493611), count: 5, class_loss = 1.386271, iou_loss = 6.924695, total_loss = 8.310967
#  total_bbox = 229142, rewritten_bbox = 0.869766 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.767690), count: 1, class_loss = 0.006790, iou_loss = 0.505741, total_loss = 0.512531
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.627650), count: 3, class_loss = 0.595899, iou_loss = 5.463566, total_loss = 6.059465
#  total_bbox = 229146, rewritten_bbox = 0.869751 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000065, iou_loss = 0.000000, total_loss = 0.000065
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.523560), count: 6, class_loss = 1.659320, iou_loss = 17.224764, total_loss = 18.884085
#  total_bbox = 229152, rewritten_bbox = 0.869728 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.004290, iou_loss = 0.000000, total_loss = 0.004290
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.674625), count: 4, class_loss = 0.823977, iou_loss = 12.765004, total_loss = 13.588982
#  total_bbox = 229156, rewritten_bbox = 0.869713 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.514445), count: 1, class_loss = 0.230594, iou_loss = 0.148817, total_loss = 0.379411
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.589347), count: 3, class_loss = 0.693072, iou_loss = 6.052605, total_loss = 6.745678
#  total_bbox = 229160, rewritten_bbox = 0.869698 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000819, iou_loss = 0.000000, total_loss = 0.000819
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.567669), count: 29, class_loss = 6.384856, iou_loss = 122.872223, total_loss = 129.257080
#  total_bbox = 229189, rewritten_bbox = 0.869588 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.001144, iou_loss = 0.000000, total_loss = 0.001144
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.622291), count: 3, class_loss = 0.948675, iou_loss = 6.582062, total_loss = 7.530737
#  total_bbox = 229192, rewritten_bbox = 0.869577 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000132, iou_loss = 0.000000, total_loss = 0.000132
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.694579), count: 3, class_loss = 0.658097, iou_loss = 13.290622, total_loss = 13.948718
#  total_bbox = 229195, rewritten_bbox = 0.869565 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5834: 0.843159, 0.708661 avg loss, 0.000026 rate, 0.652255 seconds, 140016 images, 0.434440 hours left
# Loaded: 3.987541 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.001423, iou_loss = 0.000000, total_loss = 0.001423
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.551463), count: 4, class_loss = 1.021637, iou_loss = 15.549065, total_loss = 16.570702
#  total_bbox = 229199, rewritten_bbox = 0.869550 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000026, iou_loss = 0.000000, total_loss = 0.000026
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.588942), count: 5, class_loss = 1.121479, iou_loss = 15.167473, total_loss = 16.288952
#  total_bbox = 229204, rewritten_bbox = 0.869531 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.023850, iou_loss = 0.000000, total_loss = 0.023850
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.614350), count: 2, class_loss = 0.664147, iou_loss = 2.744052, total_loss = 3.408199
#  total_bbox = 229206, rewritten_bbox = 0.869523 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000047, iou_loss = 0.000000, total_loss = 0.000047
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.524960), count: 7, class_loss = 1.830625, iou_loss = 19.436298, total_loss = 21.266924
#  total_bbox = 229213, rewritten_bbox = 0.869497 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000197, iou_loss = 0.000000, total_loss = 0.000197
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.721125), count: 1, class_loss = 0.227204, iou_loss = 1.990959, total_loss = 2.218163
#  total_bbox = 229214, rewritten_bbox = 0.869493 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000395, iou_loss = 0.000000, total_loss = 0.000395
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.622380), count: 16, class_loss = 3.602553, iou_loss = 39.563293, total_loss = 43.165848
#  total_bbox = 229230, rewritten_bbox = 0.869432 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.839626), count: 1, class_loss = 0.392512, iou_loss = 5.255651, total_loss = 5.648163
#  total_bbox = 229231, rewritten_bbox = 0.869429 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.657941), count: 2, class_loss = 0.384532, iou_loss = 0.625839, total_loss = 1.010371
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.648946), count: 1, class_loss = 0.361801, iou_loss = 0.310934, total_loss = 0.672735
#  total_bbox = 229234, rewritten_bbox = 0.869417 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5835: 0.606738, 0.698468 avg loss, 0.000026 rate, 0.624780 seconds, 140040 images, 0.432269 hours left
# Loaded: 3.958192 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.795414), count: 1, class_loss = 0.110811, iou_loss = 0.689267, total_loss = 0.800079
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.678827), count: 4, class_loss = 0.851154, iou_loss = 7.520230, total_loss = 8.371384
#  total_bbox = 229239, rewritten_bbox = 0.869398 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.587912), count: 1, class_loss = 0.280372, iou_loss = 0.061055, total_loss = 0.341427
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.640467), count: 2, class_loss = 0.812239, iou_loss = 11.039992, total_loss = 11.852231
#  total_bbox = 229242, rewritten_bbox = 0.869387 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.002325, iou_loss = 0.000000, total_loss = 0.002325
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.693846), count: 2, class_loss = 0.678169, iou_loss = 10.816543, total_loss = 11.494712
#  total_bbox = 229244, rewritten_bbox = 0.869379 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.482555), count: 1, class_loss = 0.333468, iou_loss = 0.067836, total_loss = 0.401303
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.518162), count: 1, class_loss = 0.206087, iou_loss = 4.085508, total_loss = 4.291595
#  total_bbox = 229246, rewritten_bbox = 0.869372 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.670786), count: 3, class_loss = 0.636177, iou_loss = 13.449582, total_loss = 14.085759
#  total_bbox = 229249, rewritten_bbox = 0.869360 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.006723, iou_loss = 0.000000, total_loss = 0.006723
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.661586), count: 5, class_loss = 1.050610, iou_loss = 19.094431, total_loss = 20.145041
#  total_bbox = 229254, rewritten_bbox = 0.869341 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.560445), count: 5, class_loss = 1.438493, iou_loss = 18.931826, total_loss = 20.370319
#  total_bbox = 229259, rewritten_bbox = 0.869322 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000017, iou_loss = 0.000000, total_loss = 0.000017
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.539449), count: 7, class_loss = 2.043686, iou_loss = 20.548876, total_loss = 22.592562
#  total_bbox = 229266, rewritten_bbox = 0.869732 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5836: 0.534228, 0.682044 avg loss, 0.000026 rate, 0.620167 seconds, 140064 images, 0.430060 hours left
# Loaded: 4.043787 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000187, iou_loss = 0.000000, total_loss = 0.000187
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.795696), count: 2, class_loss = 0.720228, iou_loss = 5.714914, total_loss = 6.435142
#  total_bbox = 229268, rewritten_bbox = 0.869725 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.548653), count: 1, class_loss = 0.336040, iou_loss = 0.378132, total_loss = 0.714172
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.572445), count: 3, class_loss = 1.073118, iou_loss = 6.523638, total_loss = 7.596756
#  total_bbox = 229272, rewritten_bbox = 0.869709 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.486334), count: 1, class_loss = 0.423280, iou_loss = 0.041631, total_loss = 0.464911
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.613791), count: 3, class_loss = 0.934528, iou_loss = 17.337818, total_loss = 18.272346
#  total_bbox = 229276, rewritten_bbox = 0.869694 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000309, iou_loss = 0.000000, total_loss = 0.000309
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.601090), count: 20, class_loss = 3.852885, iou_loss = 85.746437, total_loss = 89.599327
#  total_bbox = 229296, rewritten_bbox = 0.869618 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000030, iou_loss = 0.000000, total_loss = 0.000030
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.485101), count: 2, class_loss = 0.431382, iou_loss = 3.553312, total_loss = 3.984694
#  total_bbox = 229298, rewritten_bbox = 0.869611 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.653367), count: 1, class_loss = 0.334267, iou_loss = 0.580250, total_loss = 0.914516
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.751283), count: 4, class_loss = 0.879369, iou_loss = 14.572688, total_loss = 15.452057
#  total_bbox = 229303, rewritten_bbox = 0.869592 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000066, iou_loss = 0.000000, total_loss = 0.000066
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.677811), count: 7, class_loss = 1.922339, iou_loss = 28.264490, total_loss = 30.186831
#  total_bbox = 229310, rewritten_bbox = 0.869565 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000132, iou_loss = 0.000000, total_loss = 0.000132
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.401518), count: 1, class_loss = 0.341713, iou_loss = 4.062004, total_loss = 4.403717
#  total_bbox = 229311, rewritten_bbox = 0.869561 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5837: 0.709553, 0.684795 avg loss, 0.000026 rate, 0.671169 seconds, 140088 images, 0.427845 hours left
# Loaded: 3.957332 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.653155), count: 2, class_loss = 0.601618, iou_loss = 0.240577, total_loss = 0.842195
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.646644), count: 7, class_loss = 1.772149, iou_loss = 19.495161, total_loss = 21.267309
#  total_bbox = 229320, rewritten_bbox = 0.869527 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000033, iou_loss = 0.000000, total_loss = 0.000033
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.606463), count: 5, class_loss = 1.469069, iou_loss = 14.157985, total_loss = 15.627053
#  total_bbox = 229325, rewritten_bbox = 0.869508 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.741844), count: 1, class_loss = 0.115530, iou_loss = 0.406995, total_loss = 0.522525
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.667251), count: 10, class_loss = 2.466946, iou_loss = 46.620602, total_loss = 49.087543
#  total_bbox = 229336, rewritten_bbox = 0.869467 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.582793), count: 1, class_loss = 0.310559, iou_loss = 0.209690, total_loss = 0.520248
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.739012), count: 4, class_loss = 1.024545, iou_loss = 19.355814, total_loss = 20.380358
#  total_bbox = 229341, rewritten_bbox = 0.869448 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.002845, iou_loss = 0.000000, total_loss = 0.002845
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.769980), count: 1, class_loss = 0.078103, iou_loss = 1.806186, total_loss = 1.884289
#  total_bbox = 229342, rewritten_bbox = 0.869444 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000066, iou_loss = 0.000000, total_loss = 0.000066
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.679196), count: 7, class_loss = 1.796722, iou_loss = 29.812225, total_loss = 31.608948
#  total_bbox = 229349, rewritten_bbox = 0.869417 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000217, iou_loss = 0.000000, total_loss = 0.000217
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.659880), count: 2, class_loss = 0.620403, iou_loss = 6.409863, total_loss = 7.030266
#  total_bbox = 229351, rewritten_bbox = 0.869410 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000522, iou_loss = 0.000000, total_loss = 0.000522
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.693024), count: 4, class_loss = 1.026279, iou_loss = 16.769468, total_loss = 17.795748
#  total_bbox = 229355, rewritten_bbox = 0.869395 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5838: 0.710543, 0.687370 avg loss, 0.000026 rate, 0.603885 seconds, 140112 images, 0.425702 hours left
# Loaded: 3.980948 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.795253), count: 1, class_loss = 0.332753, iou_loss = 0.156924, total_loss = 0.489677
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.003068, iou_loss = 0.000000, total_loss = 0.003068
#  total_bbox = 229356, rewritten_bbox = 0.869391 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000009, iou_loss = 0.000000, total_loss = 0.000009
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.580203), count: 10, class_loss = 2.828472, iou_loss = 52.419697, total_loss = 55.248169
#  total_bbox = 229366, rewritten_bbox = 0.869353 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000062, iou_loss = 0.000000, total_loss = 0.000062
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.695604), count: 7, class_loss = 1.463166, iou_loss = 32.314167, total_loss = 33.777332
#  total_bbox = 229373, rewritten_bbox = 0.869326 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.821106), count: 1, class_loss = 0.000590, iou_loss = 0.883598, total_loss = 0.884188
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.752564), count: 6, class_loss = 1.545518, iou_loss = 16.791256, total_loss = 18.336775
#  total_bbox = 229380, rewritten_bbox = 0.869300 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.003699, iou_loss = 0.000000, total_loss = 0.003699
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.665522), count: 2, class_loss = 0.317841, iou_loss = 5.861949, total_loss = 6.179790
#  total_bbox = 229382, rewritten_bbox = 0.869292 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.736010), count: 2, class_loss = 0.639937, iou_loss = 11.554679, total_loss = 12.194615
#  total_bbox = 229384, rewritten_bbox = 0.869285 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.002066, iou_loss = 0.000000, total_loss = 0.002066
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.737111), count: 4, class_loss = 0.471816, iou_loss = 18.038893, total_loss = 18.510710
#  total_bbox = 229388, rewritten_bbox = 0.869270 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000320, iou_loss = 0.000000, total_loss = 0.000320
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.650287), count: 17, class_loss = 3.774383, iou_loss = 48.937443, total_loss = 52.711826
#  total_bbox = 229405, rewritten_bbox = 0.869641 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5839: 0.715224, 0.690155 avg loss, 0.000026 rate, 0.603522 seconds, 140136 images, 0.423497 hours left
# Loaded: 4.062222 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.693802), count: 1, class_loss = 0.148870, iou_loss = 0.031152, total_loss = 0.180022
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.536007), count: 4, class_loss = 1.380731, iou_loss = 11.978672, total_loss = 13.359403
#  total_bbox = 229410, rewritten_bbox = 0.869622 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000024, iou_loss = 0.000000, total_loss = 0.000024
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.618715), count: 4, class_loss = 1.265935, iou_loss = 13.267822, total_loss = 14.533757
#  total_bbox = 229414, rewritten_bbox = 0.869607 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000048, iou_loss = 0.000000, total_loss = 0.000048
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.548950), count: 3, class_loss = 0.761281, iou_loss = 11.029255, total_loss = 11.790536
#  total_bbox = 229417, rewritten_bbox = 0.869596 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000033, iou_loss = 0.000000, total_loss = 0.000033
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.619915), count: 5, class_loss = 1.459567, iou_loss = 19.875212, total_loss = 21.334778
#  total_bbox = 229422, rewritten_bbox = 0.869577 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000114, iou_loss = 0.000000, total_loss = 0.000114
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.645485), count: 2, class_loss = 0.451712, iou_loss = 7.609814, total_loss = 8.061526
#  total_bbox = 229424, rewritten_bbox = 0.869569 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.563001), count: 2, class_loss = 0.420076, iou_loss = 9.859447, total_loss = 10.279523
#  total_bbox = 229426, rewritten_bbox = 0.869561 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000021, iou_loss = 0.000000, total_loss = 0.000021
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.829758), count: 1, class_loss = 0.441455, iou_loss = 6.518096, total_loss = 6.959551
#  total_bbox = 229427, rewritten_bbox = 0.869558 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.609122), count: 1, class_loss = 0.147992, iou_loss = 0.242841, total_loss = 0.390833
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.591770), count: 9, class_loss = 2.344672, iou_loss = 34.516922, total_loss = 36.861595
#  total_bbox = 229437, rewritten_bbox = 0.869520 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5840: 0.556868, 0.676827 avg loss, 0.000026 rate, 0.638029 seconds, 140160 images, 0.421313 hours left
# Resizing, random_coef = 1.40
#
#  544 x 544
#  try to allocate additional workspace_size = 26.22 MB
#  CUDA allocate done!
# Loaded: 4.049239 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.601995), count: 8, class_loss = 1.905880, iou_loss = 26.395617, total_loss = 28.301497
#  total_bbox = 229445, rewritten_bbox = 0.869489 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.874418), count: 1, class_loss = 0.210094, iou_loss = 0.306910, total_loss = 0.517003
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.551951), count: 3, class_loss = 0.952101, iou_loss = 5.646657, total_loss = 6.598757
#  total_bbox = 229449, rewritten_bbox = 0.869474 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000008, iou_loss = 0.000000, total_loss = 0.000008
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.709450), count: 1, class_loss = 0.165698, iou_loss = 3.075853, total_loss = 3.241552
#  total_bbox = 229450, rewritten_bbox = 0.869470 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.671919), count: 3, class_loss = 0.554694, iou_loss = 8.750222, total_loss = 9.304916
#  total_bbox = 229453, rewritten_bbox = 0.869459 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.823591), count: 1, class_loss = 0.091120, iou_loss = 6.913699, total_loss = 7.004818
#  total_bbox = 229454, rewritten_bbox = 0.869455 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.698391), count: 3, class_loss = 0.573801, iou_loss = 9.620923, total_loss = 10.194724
#  total_bbox = 229457, rewritten_bbox = 0.869444 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.534592), count: 1, class_loss = 0.346655, iou_loss = 2.674382, total_loss = 3.021038
#  total_bbox = 229458, rewritten_bbox = 0.869440 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.622862), count: 4, class_loss = 0.717293, iou_loss = 9.061502, total_loss = 9.778795
#  total_bbox = 229462, rewritten_bbox = 0.869425 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5841: 0.349080, 0.644052 avg loss, 0.000026 rate, 0.409228 seconds, 140184 images, 0.419189 hours left
# Loaded: 4.036019 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.800255), count: 3, class_loss = 0.365891, iou_loss = 10.160234, total_loss = 10.526125
#  total_bbox = 229465, rewritten_bbox = 0.869414 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.897249), count: 1, class_loss = 0.073494, iou_loss = 1.541259, total_loss = 1.614753
#  total_bbox = 229466, rewritten_bbox = 0.869410 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000024, iou_loss = 0.000000, total_loss = 0.000024
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.044376, iou_loss = 0.000000, total_loss = 0.044376
#  total_bbox = 229466, rewritten_bbox = 0.869410 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.260927, iou_loss = 0.000000, total_loss = 0.260927
#  total_bbox = 229466, rewritten_bbox = 0.869410 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000090, iou_loss = 0.000000, total_loss = 0.000090
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.648288), count: 17, class_loss = 4.528317, iou_loss = 34.766350, total_loss = 39.294666
#  total_bbox = 229483, rewritten_bbox = 0.869345 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.563030), count: 1, class_loss = 0.214016, iou_loss = 1.195217, total_loss = 1.409233
#  total_bbox = 229484, rewritten_bbox = 0.869342 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.006458, iou_loss = 0.000000, total_loss = 0.006458
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.690685), count: 4, class_loss = 1.128648, iou_loss = 7.786057, total_loss = 8.914704
#  total_bbox = 229488, rewritten_bbox = 0.869326 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.725809), count: 1, class_loss = 0.001425, iou_loss = 0.071882, total_loss = 0.073307
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.414622), count: 1, class_loss = 0.347182, iou_loss = 1.279118, total_loss = 1.626300
#  total_bbox = 229490, rewritten_bbox = 0.869319 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5842: 0.438974, 0.623544 avg loss, 0.000026 rate, 0.463289 seconds, 140208 images, 0.416966 hours left
# Loaded: 3.928109 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.600592), count: 5, class_loss = 0.792699, iou_loss = 11.649445, total_loss = 12.442143
#  total_bbox = 229495, rewritten_bbox = 0.869300 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000150, iou_loss = 0.000000, total_loss = 0.000150
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.516449), count: 6, class_loss = 1.989976, iou_loss = 10.264240, total_loss = 12.254216
#  total_bbox = 229501, rewritten_bbox = 0.869277 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.763903), count: 1, class_loss = 0.101694, iou_loss = 3.550690, total_loss = 3.652384
#  total_bbox = 229502, rewritten_bbox = 0.869273 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000121, iou_loss = 0.000000, total_loss = 0.000121
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.501536), count: 8, class_loss = 1.489226, iou_loss = 16.969564, total_loss = 18.458792
#  total_bbox = 229510, rewritten_bbox = 0.869243 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000630, iou_loss = 0.000000, total_loss = 0.000630
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.700682), count: 1, class_loss = 0.291327, iou_loss = 3.092916, total_loss = 3.384242
#  total_bbox = 229511, rewritten_bbox = 0.869239 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.485216), count: 1, class_loss = 0.333983, iou_loss = 1.840124, total_loss = 2.174107
#  total_bbox = 229512, rewritten_bbox = 0.869236 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000089, iou_loss = 0.000000, total_loss = 0.000089
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.713436), count: 1, class_loss = 0.311886, iou_loss = 1.008756, total_loss = 1.320642
#  total_bbox = 229513, rewritten_bbox = 0.869232 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.604705), count: 5, class_loss = 0.737264, iou_loss = 9.212996, total_loss = 9.950260
#  total_bbox = 229518, rewritten_bbox = 0.869213 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5843: 0.382607, 0.599450 avg loss, 0.000026 rate, 0.452282 seconds, 140232 images, 0.414771 hours left
# Loaded: 3.954696 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000442, iou_loss = 0.000000, total_loss = 0.000442
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.630683), count: 6, class_loss = 1.379093, iou_loss = 13.058604, total_loss = 14.437697
#  total_bbox = 229524, rewritten_bbox = 0.869190 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000019, iou_loss = 0.000000, total_loss = 0.000019
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.685409), count: 2, class_loss = 0.524275, iou_loss = 4.377371, total_loss = 4.901646
#  total_bbox = 229526, rewritten_bbox = 0.869183 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000065, iou_loss = 0.000000, total_loss = 0.000065
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.554321), count: 3, class_loss = 1.074762, iou_loss = 5.218722, total_loss = 6.293484
#  total_bbox = 229529, rewritten_bbox = 0.869171 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.422824), count: 2, class_loss = 0.556441, iou_loss = 2.905320, total_loss = 3.461761
#  total_bbox = 229531, rewritten_bbox = 0.869164 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.468683), count: 2, class_loss = 0.381616, iou_loss = 3.519715, total_loss = 3.901332
#  total_bbox = 229533, rewritten_bbox = 0.869156 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.729271), count: 1, class_loss = 0.133861, iou_loss = 0.308649, total_loss = 0.442510
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.893925), count: 1, class_loss = 0.074096, iou_loss = 0.417186, total_loss = 0.491282
#  total_bbox = 229535, rewritten_bbox = 0.869148 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.663817), count: 4, class_loss = 0.659818, iou_loss = 11.085490, total_loss = 11.745308
#  total_bbox = 229539, rewritten_bbox = 0.869133 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.010912, iou_loss = 0.000000, total_loss = 0.010912
#  total_bbox = 229539, rewritten_bbox = 0.869133 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5844: 0.304017, 0.569907 avg loss, 0.000026 rate, 0.450402 seconds, 140256 images, 0.412534 hours left
# Loaded: 4.160039 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000025, iou_loss = 0.000000, total_loss = 0.000025
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.572183), count: 3, class_loss = 0.925450, iou_loss = 6.677531, total_loss = 7.602981
#  total_bbox = 229542, rewritten_bbox = 0.869122 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000295, iou_loss = 0.000000, total_loss = 0.000295
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.500386), count: 5, class_loss = 1.450680, iou_loss = 6.502635, total_loss = 7.953314
#  total_bbox = 229547, rewritten_bbox = 0.869103 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000021, iou_loss = 0.000000, total_loss = 0.000021
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.617345), count: 11, class_loss = 2.853485, iou_loss = 26.348742, total_loss = 29.202227
#  total_bbox = 229558, rewritten_bbox = 0.869061 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.562285), count: 4, class_loss = 1.428552, iou_loss = 8.572481, total_loss = 10.001033
#  total_bbox = 229562, rewritten_bbox = 0.869046 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.829797), count: 2, class_loss = 0.692033, iou_loss = 4.158638, total_loss = 4.850670
#  total_bbox = 229564, rewritten_bbox = 0.869039 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.589766), count: 4, class_loss = 1.107818, iou_loss = 7.302250, total_loss = 8.410069
#  total_bbox = 229568, rewritten_bbox = 0.869024 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000106, iou_loss = 0.000000, total_loss = 0.000106
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.434659), count: 1, class_loss = 0.425389, iou_loss = 1.205032, total_loss = 1.630420
#  total_bbox = 229569, rewritten_bbox = 0.869020 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.067530, iou_loss = 0.000000, total_loss = 0.067530
#  total_bbox = 229569, rewritten_bbox = 0.869020 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5845: 0.563682, 0.569284 avg loss, 0.000026 rate, 0.407754 seconds, 140280 images, 0.410317 hours left
# Loaded: 3.985394 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000002, iou_loss = 0.000000, total_loss = 0.000002
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.546216), count: 2, class_loss = 0.597540, iou_loss = 5.717627, total_loss = 6.315167
#  total_bbox = 229571, rewritten_bbox = 0.869012 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.729440), count: 2, class_loss = 0.421399, iou_loss = 6.027403, total_loss = 6.448802
#  total_bbox = 229573, rewritten_bbox = 0.869005 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.554468), count: 5, class_loss = 1.093460, iou_loss = 9.896409, total_loss = 10.989869
#  total_bbox = 229578, rewritten_bbox = 0.868986 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.002405, iou_loss = 0.000000, total_loss = 0.002405
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.762591), count: 1, class_loss = 0.253858, iou_loss = 4.885660, total_loss = 5.139518
#  total_bbox = 229579, rewritten_bbox = 0.868982 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.680847), count: 1, class_loss = 0.182471, iou_loss = 2.476285, total_loss = 2.658757
#  total_bbox = 229580, rewritten_bbox = 0.868978 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.677923), count: 1, class_loss = 0.332893, iou_loss = 0.229804, total_loss = 0.562697
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.568712), count: 2, class_loss = 0.794535, iou_loss = 1.065112, total_loss = 1.859647
#  total_bbox = 229583, rewritten_bbox = 0.868967 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000017, iou_loss = 0.000000, total_loss = 0.000017
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.681724), count: 3, class_loss = 0.699679, iou_loss = 7.270069, total_loss = 7.969748
#  total_bbox = 229586, rewritten_bbox = 0.868955 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000008, iou_loss = 0.000000, total_loss = 0.000008
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.773515), count: 3, class_loss = 0.676032, iou_loss = 9.400186, total_loss = 10.076219
#  total_bbox = 229589, rewritten_bbox = 0.868944 %
#
#  (next mAP calculation at 5865 iterations)
#  Last accuracy mAP@0.5 = 17.84 %, best = 18.18 %
#  5846: 0.320305, 0.544387 avg loss, 0.000026 rate, 0.425171 seconds, 140304 images, 0.408181 hours left
# Loaded: 4.047002 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.790023), count: 2, class_loss = 0.424461, iou_loss = 7.649738, total_loss = 8.074199
#  total_bbox = 229591, rewritten_bbox = 0.868936 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000006, iou_loss = 0.000000, total_loss = 0.000006
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.010964, iou_loss = 0.000000, total_loss = 0.010964
#  total_bbox = 229591, rewritten_bbox = 0.868936 %
# ...
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.609740), count: 4, class_loss = 1.159913, iou_loss = 21.982439, total_loss = 23.142351
#  total_bbox = 236726, rewritten_bbox = 0.870204 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000619, iou_loss = 0.000000, total_loss = 0.000619
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.563390), count: 16, class_loss = 4.524343, iou_loss = 72.609253, total_loss = 77.133598
#  total_bbox = 236742, rewritten_bbox = 0.870146 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.422563), count: 1, class_loss = 0.333422, iou_loss = 0.008783, total_loss = 0.342205
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.557281), count: 3, class_loss = 1.151080, iou_loss = 5.395658, total_loss = 6.546739
#  total_bbox = 236746, rewritten_bbox = 0.870131 %
#
#  (next mAP calculation at 6004 iterations)
#  Last accuracy mAP@0.5 = 18.02 %, best = 18.18 %
#  5996: 1.141351, 1.024787 avg loss, 0.000026 rate, 1.009275 seconds, 143904 images, 0.178191 hours left
# Loaded: 3.793427 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000212, iou_loss = 0.000000, total_loss = 0.000212
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.700141), count: 3, class_loss = 0.442592, iou_loss = 18.892988, total_loss = 19.335581
#  total_bbox = 236749, rewritten_bbox = 0.870120 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000042, iou_loss = 0.000000, total_loss = 0.000042
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.513379), count: 6, class_loss = 2.086810, iou_loss = 21.546186, total_loss = 23.632996
#  total_bbox = 236755, rewritten_bbox = 0.870098 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.645256), count: 2, class_loss = 0.353720, iou_loss = 1.157108, total_loss = 1.510828
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.671714), count: 3, class_loss = 1.027478, iou_loss = 3.877080, total_loss = 4.904558
#  total_bbox = 236760, rewritten_bbox = 0.870079 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000046, iou_loss = 0.000000, total_loss = 0.000046
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.581070), count: 8, class_loss = 2.421819, iou_loss = 41.101818, total_loss = 43.523636
#  total_bbox = 236768, rewritten_bbox = 0.870050 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.003648, iou_loss = 0.000000, total_loss = 0.003648
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.472462), count: 15, class_loss = 4.184125, iou_loss = 50.232086, total_loss = 54.416210
#  total_bbox = 236783, rewritten_bbox = 0.870840 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000203, iou_loss = 0.000000, total_loss = 0.000203
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.410155), count: 17, class_loss = 5.672822, iou_loss = 64.444710, total_loss = 70.117531
#  total_bbox = 236800, rewritten_bbox = 0.870777 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.713196), count: 1, class_loss = 0.086321, iou_loss = 0.182295, total_loss = 0.268617
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.765507), count: 4, class_loss = 1.099193, iou_loss = 18.630508, total_loss = 19.729702
#  total_bbox = 236805, rewritten_bbox = 0.870759 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.722174), count: 1, class_loss = 0.366008, iou_loss = 0.613635, total_loss = 0.979642
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.663240), count: 18, class_loss = 2.974632, iou_loss = 132.341629, total_loss = 135.316254
#  total_bbox = 236824, rewritten_bbox = 0.870689 %
#
#  (next mAP calculation at 6004 iterations)
#  Last accuracy mAP@0.5 = 18.02 %, best = 18.18 %
#  5997: 1.301020, 1.052410 avg loss, 0.000026 rate, 0.980432 seconds, 143928 images, 0.176464 hours left
# Loaded: 3.922260 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000394, iou_loss = 0.000000, total_loss = 0.000394
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.737264), count: 4, class_loss = 0.773895, iou_loss = 27.730675, total_loss = 28.504570
#  total_bbox = 236828, rewritten_bbox = 0.870674 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000544, iou_loss = 0.000000, total_loss = 0.000544
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.688050), count: 5, class_loss = 1.390468, iou_loss = 28.443832, total_loss = 29.834299
#  total_bbox = 236833, rewritten_bbox = 0.870656 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000317, iou_loss = 0.000000, total_loss = 0.000317
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.654548), count: 10, class_loss = 2.004271, iou_loss = 60.448399, total_loss = 62.452671
#  total_bbox = 236843, rewritten_bbox = 0.870619 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.660443), count: 1, class_loss = 0.333337, iou_loss = 1.039051, total_loss = 1.372388
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.623740), count: 4, class_loss = 1.286039, iou_loss = 11.383805, total_loss = 12.669846
#  total_bbox = 236848, rewritten_bbox = 0.870601 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000292, iou_loss = 0.000000, total_loss = 0.000292
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.539605), count: 7, class_loss = 2.219799, iou_loss = 21.610382, total_loss = 23.830179
#  total_bbox = 236855, rewritten_bbox = 0.870575 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000875, iou_loss = 0.000000, total_loss = 0.000875
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.616478), count: 5, class_loss = 1.392320, iou_loss = 25.797159, total_loss = 27.189478
#  total_bbox = 236860, rewritten_bbox = 0.870556 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.005266, iou_loss = 0.000000, total_loss = 0.005266
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.499424), count: 5, class_loss = 1.754022, iou_loss = 21.156452, total_loss = 22.910475
#  total_bbox = 236865, rewritten_bbox = 0.870538 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.845601), count: 1, class_loss = 0.032960, iou_loss = 1.156518, total_loss = 1.189478
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.715724), count: 4, class_loss = 1.191882, iou_loss = 14.392108, total_loss = 15.583989
#  total_bbox = 236870, rewritten_bbox = 0.870520 %
#
#  (next mAP calculation at 6004 iterations)
#  Last accuracy mAP@0.5 = 18.02 %, best = 18.18 %
#  5998: 0.779154, 1.025084 avg loss, 0.000026 rate, 1.013596 seconds, 143952 images, 0.174740 hours left
# Loaded: 3.850408 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000164, iou_loss = 0.000000, total_loss = 0.000164
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.577797), count: 5, class_loss = 1.368868, iou_loss = 28.875093, total_loss = 30.243963
#  total_bbox = 236875, rewritten_bbox = 0.870501 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000132, iou_loss = 0.000000, total_loss = 0.000132
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.629185), count: 3, class_loss = 1.040952, iou_loss = 14.419726, total_loss = 15.460678
#  total_bbox = 236878, rewritten_bbox = 0.870490 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.005608, iou_loss = 0.000000, total_loss = 0.005608
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.761349), count: 3, class_loss = 0.297956, iou_loss = 19.203917, total_loss = 19.501871
#  total_bbox = 236881, rewritten_bbox = 0.870479 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000134, iou_loss = 0.000000, total_loss = 0.000134
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.503526), count: 12, class_loss = 3.675938, iou_loss = 50.170681, total_loss = 53.846619
#  total_bbox = 236893, rewritten_bbox = 0.870857 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000116, iou_loss = 0.000000, total_loss = 0.000116
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.359334), count: 1, class_loss = 0.411606, iou_loss = 2.179042, total_loss = 2.590647
#  total_bbox = 236894, rewritten_bbox = 0.870854 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.642801), count: 3, class_loss = 0.805056, iou_loss = 1.719789, total_loss = 2.524845
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.670342), count: 4, class_loss = 1.017284, iou_loss = 10.427670, total_loss = 11.444954
#  total_bbox = 236901, rewritten_bbox = 0.870828 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.100784, iou_loss = 0.000000, total_loss = 0.100784
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.561103), count: 4, class_loss = 0.912688, iou_loss = 7.559529, total_loss = 8.472217
#  total_bbox = 236905, rewritten_bbox = 0.870813 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000316, iou_loss = 0.000000, total_loss = 0.000316
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.539916), count: 12, class_loss = 2.643297, iou_loss = 47.266323, total_loss = 49.909618
#  total_bbox = 236917, rewritten_bbox = 0.871613 %
#
#  (next mAP calculation at 6004 iterations)
#  Last accuracy mAP@0.5 = 18.02 %, best = 18.18 %
#  5999: 0.773032, 0.999879 avg loss, 0.000026 rate, 0.948748 seconds, 143976 images, 0.173020 hours left
# Loaded: 2.950196 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000033, iou_loss = 0.000000, total_loss = 0.000033
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.613443), count: 7, class_loss = 1.972191, iou_loss = 46.045856, total_loss = 48.018051
#  total_bbox = 236924, rewritten_bbox = 0.871588 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.788478), count: 1, class_loss = 0.031997, iou_loss = 0.293287, total_loss = 0.325284
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.633039), count: 3, class_loss = 0.650175, iou_loss = 8.236388, total_loss = 8.886562
#  total_bbox = 236928, rewritten_bbox = 0.871573 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.490724), count: 1, class_loss = 0.310002, iou_loss = 0.013110, total_loss = 0.323112
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.519155), count: 10, class_loss = 2.734374, iou_loss = 42.600292, total_loss = 45.334667
#  total_bbox = 236939, rewritten_bbox = 0.871532 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000134, iou_loss = 0.000000, total_loss = 0.000134
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.638872), count: 4, class_loss = 1.523427, iou_loss = 13.808290, total_loss = 15.331717
#  total_bbox = 236943, rewritten_bbox = 0.871518 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.001099, iou_loss = 0.000000, total_loss = 0.001099
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.608404), count: 8, class_loss = 2.479315, iou_loss = 36.645130, total_loss = 39.124447
#  total_bbox = 236951, rewritten_bbox = 0.871488 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000013, iou_loss = 0.000000, total_loss = 0.000013
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.579487), count: 12, class_loss = 3.696018, iou_loss = 55.045120, total_loss = 58.741138
#  total_bbox = 236963, rewritten_bbox = 0.871444 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000021, iou_loss = 0.000000, total_loss = 0.000021
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.512963), count: 8, class_loss = 2.541167, iou_loss = 33.743507, total_loss = 36.284676
#  total_bbox = 236971, rewritten_bbox = 0.871415 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.534649), count: 1, class_loss = 0.334381, iou_loss = 0.135517, total_loss = 0.469897
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.648375), count: 21, class_loss = 4.178076, iou_loss = 94.957268, total_loss = 99.135345
#  total_bbox = 236993, rewritten_bbox = 0.871334 %
#
#  (next mAP calculation at 6004 iterations)
#  Last accuracy mAP@0.5 = 18.02 %, best = 18.18 %
#  6000: 1.284740, 1.028365 avg loss, 0.000026 rate, 1.032236 seconds, 144000 images, 0.171303 hours left
# Resizing to initial size: 608 x 608  try to allocate additional workspace_size = 26.22 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 28
#  Detection layer: 37 - type = 28
# 1000
#  detections_count = 7652, unique_truth_count = 859
# class_id = 0, name = fish, ap = 17.13%   	 (TP = 162, FP = 162)
#
#  for conf_thresh = 0.25, precision = 0.50, recall = 0.19, F1-score = 0.27
#  for conf_thresh = 0.25, TP = 162, FP = 162, FN = 697, average IoU = 33.47 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.171309, or 17.13 %
# Total Detection Time: 253 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.171309
# Saving weights to /mydrive/INTERNS/CLARE/YOLO_main/backup_b/yolov4-tiny_6000.weights
# Saving weights to /mydrive/INTERNS/CLARE/YOLO_main/backup_b/yolov4-tiny_last.weights
# Saving weights to /mydrive/INTERNS/CLARE/YOLO_main/backup_b/yolov4-tiny_final.weights
# If you want to train from the beginning, then use flag in the end of training command: -clear

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# start training again from previous weights
# !./darknet detector train data/obj.data cfg/yolov4-tiny.cfg /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_last.weights -dont_show -map

# %% [markdown]
# Start training again from previous weights

# %% [markdown]
# # Step 6: Checking the Mean Average Precision (mAP) of Your Model

# %%
# !./darknet detector map data/obj.data cfg/yolov4-tiny.cfg /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_1000.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    608 x 608 x   3 ->  304 x 304 x  32 0.160 BF
#    1 conv     64       3 x 3/ 2    304 x 304 x  32 ->  152 x 152 x  64 0.852 BF
#    2 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#    3 route  2 		                       1/2 ->  152 x 152 x  32
#    4 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    5 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    6 route  5 4 	                           ->  152 x 152 x  64
#    7 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#    8 route  2 7 	                           ->  152 x 152 x 128
#    9 max                2x 2/ 2    152 x 152 x 128 ->   76 x  76 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   11 route  10 		                       1/2 ->   76 x  76 x  64
#   12 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   13 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   14 route  13 12 	                           ->   76 x  76 x 128
#   15 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   16 route  10 15 	                           ->   76 x  76 x 256
#   17 max                2x 2/ 2     76 x  76 x 256 ->   38 x  38 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   19 route  18 		                       1/2 ->   38 x  38 x 128
#   20 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   21 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   22 route  21 20 	                           ->   38 x  38 x 256
#   23 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   24 route  18 23 	                           ->   38 x  38 x 512
#   25 max                2x 2/ 2     38 x  38 x 512 ->   19 x  19 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   27 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   28 conv    512       3 x 3/ 1     19 x  19 x 256 ->   19 x  19 x 512 0.852 BF
#   29 conv     18       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x  18 0.007 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#   31 route  27 		                           ->   19 x  19 x 256
#   32 conv    128       1 x 1/ 1     19 x  19 x 256 ->   19 x  19 x 128 0.024 BF
#   33 upsample                 2x    19 x  19 x 128 ->   38 x  38 x 128
#   34 route  33 23 	                           ->   38 x  38 x 384
#   35 conv    256       3 x 3/ 1     38 x  38 x 384 ->   38 x  38 x 256 2.555 BF
#   36 conv     18       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x  18 0.013 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 14.498
# avg_outputs = 640110
#  Allocate additional workspace_size = 26.22 MB
# Loading weights from /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_1000.weights...
#  seen 64, trained: 24 K-images (0 Kilo-batches_64)
# Done! Loaded 38 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 28
#  Detection layer: 37 - type = 28
# 596
#  detections_count = 2903, unique_truth_count = 294
# class_id = 0, name = fish, ap = 1.54%   	 (TP = 2, FP = 1)
#
#  for conf_thresh = 0.25, precision = 0.67, recall = 0.01, F1-score = 0.01
#  for conf_thresh = 0.25, TP = 2, FP = 1, FN = 292, average IoU = 40.02 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.015381, or 1.54 %
# Total Detection Time: 168 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map data/obj.data cfg/yolov4-tiny.cfg /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_2000.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    608 x 608 x   3 ->  304 x 304 x  32 0.160 BF
#    1 conv     64       3 x 3/ 2    304 x 304 x  32 ->  152 x 152 x  64 0.852 BF
#    2 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#    3 route  2 		                       1/2 ->  152 x 152 x  32
#    4 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    5 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    6 route  5 4 	                           ->  152 x 152 x  64
#    7 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#    8 route  2 7 	                           ->  152 x 152 x 128
#    9 max                2x 2/ 2    152 x 152 x 128 ->   76 x  76 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   11 route  10 		                       1/2 ->   76 x  76 x  64
#   12 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   13 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   14 route  13 12 	                           ->   76 x  76 x 128
#   15 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   16 route  10 15 	                           ->   76 x  76 x 256
#   17 max                2x 2/ 2     76 x  76 x 256 ->   38 x  38 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   19 route  18 		                       1/2 ->   38 x  38 x 128
#   20 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   21 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   22 route  21 20 	                           ->   38 x  38 x 256
#   23 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   24 route  18 23 	                           ->   38 x  38 x 512
#   25 max                2x 2/ 2     38 x  38 x 512 ->   19 x  19 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   27 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   28 conv    512       3 x 3/ 1     19 x  19 x 256 ->   19 x  19 x 512 0.852 BF
#   29 conv     18       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x  18 0.007 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#   31 route  27 		                           ->   19 x  19 x 256
#   32 conv    128       1 x 1/ 1     19 x  19 x 256 ->   19 x  19 x 128 0.024 BF
#   33 upsample                 2x    19 x  19 x 128 ->   38 x  38 x 128
#   34 route  33 23 	                           ->   38 x  38 x 384
#   35 conv    256       3 x 3/ 1     38 x  38 x 384 ->   38 x  38 x 256 2.555 BF
#   36 conv     18       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x  18 0.013 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 14.498
# avg_outputs = 640110
#  Allocate additional workspace_size = 26.22 MB
# Loading weights from /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_2000.weights...
#  seen 64, trained: 48 K-images (0 Kilo-batches_64)
# Done! Loaded 38 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 28
#  Detection layer: 37 - type = 28
# 596
#  detections_count = 3564, unique_truth_count = 294
# class_id = 0, name = fish, ap = 11.31%   	 (TP = 30, FP = 37)
#
#  for conf_thresh = 0.25, precision = 0.45, recall = 0.10, F1-score = 0.17
#  for conf_thresh = 0.25, TP = 30, FP = 37, FN = 264, average IoU = 27.31 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.113135, or 11.31 %
# Total Detection Time: 168 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map data/obj.data cfg/yolov4-tiny.cfg /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_3000.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    608 x 608 x   3 ->  304 x 304 x  32 0.160 BF
#    1 conv     64       3 x 3/ 2    304 x 304 x  32 ->  152 x 152 x  64 0.852 BF
#    2 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#    3 route  2 		                       1/2 ->  152 x 152 x  32
#    4 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    5 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    6 route  5 4 	                           ->  152 x 152 x  64
#    7 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#    8 route  2 7 	                           ->  152 x 152 x 128
#    9 max                2x 2/ 2    152 x 152 x 128 ->   76 x  76 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   11 route  10 		                       1/2 ->   76 x  76 x  64
#   12 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   13 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   14 route  13 12 	                           ->   76 x  76 x 128
#   15 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   16 route  10 15 	                           ->   76 x  76 x 256
#   17 max                2x 2/ 2     76 x  76 x 256 ->   38 x  38 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   19 route  18 		                       1/2 ->   38 x  38 x 128
#   20 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   21 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   22 route  21 20 	                           ->   38 x  38 x 256
#   23 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   24 route  18 23 	                           ->   38 x  38 x 512
#   25 max                2x 2/ 2     38 x  38 x 512 ->   19 x  19 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   27 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   28 conv    512       3 x 3/ 1     19 x  19 x 256 ->   19 x  19 x 512 0.852 BF
#   29 conv     18       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x  18 0.007 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#   31 route  27 		                           ->   19 x  19 x 256
#   32 conv    128       1 x 1/ 1     19 x  19 x 256 ->   19 x  19 x 128 0.024 BF
#   33 upsample                 2x    19 x  19 x 128 ->   38 x  38 x 128
#   34 route  33 23 	                           ->   38 x  38 x 384
#   35 conv    256       3 x 3/ 1     38 x  38 x 384 ->   38 x  38 x 256 2.555 BF
#   36 conv     18       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x  18 0.013 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 14.498
# avg_outputs = 640110
#  Allocate additional workspace_size = 26.22 MB
# Loading weights from /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_3000.weights...
#  seen 64, trained: 72 K-images (1 Kilo-batches_64)
# Done! Loaded 38 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 28
#  Detection layer: 37 - type = 28
# 596
#  detections_count = 2086, unique_truth_count = 294
# class_id = 0, name = fish, ap = 12.78%   	 (TP = 35, FP = 50)
#
#  for conf_thresh = 0.25, precision = 0.41, recall = 0.12, F1-score = 0.18
#  for conf_thresh = 0.25, TP = 35, FP = 50, FN = 259, average IoU = 26.64 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.127763, or 12.78 %
# Total Detection Time: 171 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map data/obj.data cfg/yolov4-tiny.cfg /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_4000.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    608 x 608 x   3 ->  304 x 304 x  32 0.160 BF
#    1 conv     64       3 x 3/ 2    304 x 304 x  32 ->  152 x 152 x  64 0.852 BF
#    2 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#    3 route  2 		                       1/2 ->  152 x 152 x  32
#    4 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    5 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    6 route  5 4 	                           ->  152 x 152 x  64
#    7 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#    8 route  2 7 	                           ->  152 x 152 x 128
#    9 max                2x 2/ 2    152 x 152 x 128 ->   76 x  76 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   11 route  10 		                       1/2 ->   76 x  76 x  64
#   12 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   13 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   14 route  13 12 	                           ->   76 x  76 x 128
#   15 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   16 route  10 15 	                           ->   76 x  76 x 256
#   17 max                2x 2/ 2     76 x  76 x 256 ->   38 x  38 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   19 route  18 		                       1/2 ->   38 x  38 x 128
#   20 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   21 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   22 route  21 20 	                           ->   38 x  38 x 256
#   23 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   24 route  18 23 	                           ->   38 x  38 x 512
#   25 max                2x 2/ 2     38 x  38 x 512 ->   19 x  19 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   27 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   28 conv    512       3 x 3/ 1     19 x  19 x 256 ->   19 x  19 x 512 0.852 BF
#   29 conv     18       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x  18 0.007 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#   31 route  27 		                           ->   19 x  19 x 256
#   32 conv    128       1 x 1/ 1     19 x  19 x 256 ->   19 x  19 x 128 0.024 BF
#   33 upsample                 2x    19 x  19 x 128 ->   38 x  38 x 128
#   34 route  33 23 	                           ->   38 x  38 x 384
#   35 conv    256       3 x 3/ 1     38 x  38 x 384 ->   38 x  38 x 256 2.555 BF
#   36 conv     18       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x  18 0.013 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 14.498
# avg_outputs = 640110
#  Allocate additional workspace_size = 26.22 MB
# Loading weights from /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_4000.weights...
#  seen 64, trained: 96 K-images (1 Kilo-batches_64)
# Done! Loaded 38 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 28
#  Detection layer: 37 - type = 28
# 596
#  detections_count = 1124, unique_truth_count = 294
# class_id = 0, name = fish, ap = 13.65%   	 (TP = 34, FP = 56)
#
#  for conf_thresh = 0.25, precision = 0.38, recall = 0.12, F1-score = 0.18
#  for conf_thresh = 0.25, TP = 34, FP = 56, FN = 260, average IoU = 24.09 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.136495, or 13.65 %
# Total Detection Time: 169 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map data/obj.data cfg/yolov4-tiny.cfg /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_5000.weights

# %%
# !./darknet detector test data/obj.data cfg/yolov4-tiny.cfg /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_final.weights -dont_show < data/train.txt > result.txt
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    608 x 608 x   3 ->  304 x 304 x  32 0.160 BF
#    1 conv     64       3 x 3/ 2    304 x 304 x  32 ->  152 x 152 x  64 0.852 BF
#    2 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#    3 route  2 		                       1/2 ->  152 x 152 x  32
#    4 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    5 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    6 route  5 4 	                           ->  152 x 152 x  64
#    7 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#    8 route  2 7 	                           ->  152 x 152 x 128
#    9 max                2x 2/ 2    152 x 152 x 128 ->   76 x  76 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   11 route  10 		                       1/2 ->   76 x  76 x  64
#   12 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   13 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   14 route  13 12 	                           ->   76 x  76 x 128
#   15 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   16 route  10 15 	                           ->   76 x  76 x 256
#   17 max                2x 2/ 2     76 x  76 x 256 ->   38 x  38 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   19 route  18 		                       1/2 ->   38 x  38 x 128
#   20 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   21 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   22 route  21 20 	                           ->   38 x  38 x 256
#   23 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   24 route  18 23 	                           ->   38 x  38 x 512
#   25 max                2x 2/ 2     38 x  38 x 512 ->   19 x  19 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   27 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   28 conv    512       3 x 3/ 1     19 x  19 x 256 ->   19 x  19 x 512 0.852 BF
#   29 conv     18       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x  18 0.007 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
#   31 route  27 		                           ->   19 x  19 x 256
#   32 conv    128       1 x 1/ 1     19 x  19 x 256 ->   19 x  19 x 128 0.024 BF
#   33 upsample                 2x    19 x  19 x 128 ->   38 x  38 x 128
#   34 route  33 23 	                           ->   38 x  38 x 384
#   35 conv    256       3 x 3/ 1     38 x  38 x 384 ->   38 x  38 x 256 2.555 BF
#   36 conv     18       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x  18 0.013 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# Total BFLOPS 14.498
# avg_outputs = 640110
#  Allocate additional workspace_size = 26.22 MB
# Loading weights from /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_final.weights...Done! Loaded 38 layers from weights-file

# %%
# !./darknet detector test data/obj.data cfg/yolov4-tiny.cfg /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_final.weights -dont_show < data/test.txt > result_test.txt
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    608 x 608 x   3 ->  304 x 304 x  32 0.160 BF
#    1 conv     64       3 x 3/ 2    304 x 304 x  32 ->  152 x 152 x  64 0.852 BF
#    2 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#    3 route  2 		                       1/2 ->  152 x 152 x  32
#    4 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    5 conv     32       3 x 3/ 1    152 x 152 x  32 ->  152 x 152 x  32 0.426 BF
#    6 route  5 4 	                           ->  152 x 152 x  64
#    7 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#    8 route  2 7 	                           ->  152 x 152 x 128
#    9 max                2x 2/ 2    152 x 152 x 128 ->   76 x  76 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   11 route  10 		                       1/2 ->   76 x  76 x  64
#   12 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   13 conv     64       3 x 3/ 1     76 x  76 x  64 ->   76 x  76 x  64 0.426 BF
#   14 route  13 12 	                           ->   76 x  76 x 128
#   15 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   16 route  10 15 	                           ->   76 x  76 x 256
#   17 max                2x 2/ 2     76 x  76 x 256 ->   38 x  38 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   19 route  18 		                       1/2 ->   38 x  38 x 128
#   20 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   21 conv    128       3 x 3/ 1     38 x  38 x 128 ->   38 x  38 x 128 0.426 BF
#   22 route  21 20 	                           ->   38 x  38 x 256
#   23 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   24 route  18 23 	                           ->   38 x  38 x 512
#   25 max                2x 2/ 2     38 x  38 x 512 ->   19 x  19 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   27 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   28 conv    512       3 x 3/ 1     19 x  19 x 256 ->   19 x  19 x 512 0.852 BF
#   29 conv     18       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x  18 0.007 BF
#   30 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
#   31 route  27 		                           ->   19 x  19 x 256
#   32 conv    128       1 x 1/ 1     19 x  19 x 256 ->   19 x  19 x 128 0.024 BF
#   33 upsample                 2x    19 x  19 x 128 ->   38 x  38 x 128
#   34 route  33 23 	                           ->   38 x  38 x 384
#   35 conv    256       3 x 3/ 1     38 x  38 x 384 ->   38 x  38 x 256 2.555 BF
#   36 conv     18       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x  18 0.013 BF
#   37 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# Total BFLOPS 14.498
# avg_outputs = 640110
#  Allocate additional workspace_size = 26.22 MB
# Loading weights from /mydrive/INTERNS/CLARE/YOLO_main/backup/yolov4-tiny_final.weights...Done! Loaded 38 layers from weights-file

# %% [markdown]
# # Step 7: Run Your Custom Object Detector!!!
# You have done it! You now have a custom object detector to make your very own detections. Time to test it out and have some fun!

# %%
# need to set our custom cfg to test mode 
# %cd /content/darknet/cfg
# !sed -i 's/batch=64/batch=64/' yolov4-tiny.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' yolov4-tiny.cfg
# Out:
# /content/darknet/cfg

# %%
# %cd ..
# %cd /content/darknet
# Out:
# /content/darknet
# /content/darknet

# %%
import glob
images = glob.glob('data/test/*.JPG')
texts = glob.glob('data/test/*.txt')

# %%
images.sort()
texts.sort()

# %%
t = texts[0]

# %%
for t in texts:
  # !wc -l $t
# Out:
# 0 data/test/180716_113956.txt
# 0 data/test/180713_131303.txt
# 0 data/test/180716_152701.txt
# 0 data/test/180717_181536.txt
# 0 data/test/180716_123702.txt
# 0 data/test/180716_193803.txt
# 0 data/test/180712_105001.txt
# 18 data/test/180715_130103.txt
# 1 data/test/180717_150103.txt
# 0 data/test/180715_163708.txt
# 0 data/test/180713_154932.txt
# 0 data/test/180716_123925.txt
# 0 data/test/180712_112508.txt
# 0 data/test/180716_152752.txt
# 0 data/test/180716_185110.txt
# 0 data/test/180716_151351.txt
# 0 data/test/180713_061344.txt
# 0 data/test/180715_083958.txt
# 0 data/test/180718_182546.txt
# 0 data/test/180712_102708.txt
# 0 data/test/180718_141331.txt
# 0 data/test/180716_170159.txt
# 4 data/test/180712_110102.txt
# 0 data/test/180716_162516.txt
# 0 data/test/180716_161601.txt
# 0 data/test/180715_194914.txt
# 6 data/test/180713_142509.txt
# 0 data/test/180715_111510.txt
# 0 data/test/180712_123703.txt
# 2 data/test/180715_182602.txt
# 0 data/test/180712_180116.txt
# 0 data/test/180714_182740.txt
# 1 data/test/180712_153947.txt
# 0 data/test/180713_163707.txt
# 0 data/test/180716_195017.txt
# 0 data/test/180717_152533.txt
# 0 data/test/180714_140109.txt
# 0 data/test/180716_113720.txt
# 1 data/test/180716_172733.txt
# 2 data/test/180714_163728.txt
# 0 data/test/180717_200404.txt
# 0 data/test/180714_143703.txt
# 0 data/test/180715_054902.txt
# 0 data/test/180714_192609.txt
# 0 data/test/180717_192531.txt
# 0 data/test/180712_171502.txt
# 0 data/test/180717_062556.txt
# 0 data/test/180713_055104.txt
# 1 data/test/180715_144923.txt
# 2 data/test/180712_152538.txt
# 0 data/test/180712_200110.txt
# 0 data/test/180717_085134.txt
# 0 data/test/180716_145009.txt
# 0 data/test/180715_195137.txt
# 1 data/test/180714_132747.txt
# 0 data/test/180716_140400.txt
# 0 data/test/180718_083918.txt
# 2 data/test/180712_153955.txt
# 0 data/test/180717_144903.txt
# 0 data/test/180712_060319.txt
# 0 data/test/180718_141410.txt
# 0 data/test/180712_103719.txt
# 0 data/test/180712_133719.txt
# 10 data/test/180714_185202.txt
# 0 data/test/180717_103908.txt
# 0 data/test/180714_141315.txt
# 0 data/test/180712_174943.txt
# 0 data/test/180716_175005.txt
# 0 data/test/180717_093915.txt
# 0 data/test/180713_122708.txt
# 0 data/test/180714_175003.txt
# 0 data/test/180716_160317.txt
# 0 data/test/180716_130259.txt
# 0 data/test/180713_113730.txt
# 0 data/test/180717_184932.txt
# 0 data/test/180713_080109.txt
# 0 data/test/180716_190415.txt
# 0 data/test/180715_173802.txt
# 0 data/test/180713_201558.txt
# 0 data/test/180718_191526.txt
# 0 data/test/180713_152743.txt
# 0 data/test/180713_162613.txt
# 0 data/test/180715_153919.txt
# 1 data/test/180714_170321.txt
# 0 data/test/180715_083924.txt
# 0 data/test/180715_153801.txt
# 1 data/test/180712_123733.txt
# 1 data/test/180716_184950.txt
# 0 data/test/180716_182526.txt
# 0 data/test/180714_062614.txt
# 0 data/test/180716_095133.txt
# 0 data/test/180713_182615.txt
# 0 data/test/180712_163930.txt
# 0 data/test/180713_151457.txt
# 0 data/test/180713_092742.txt
# 2 data/test/180716_190328.txt
# 0 data/test/180715_153703.txt
# 0 data/test/180717_093858.txt
# 18 data/test/180714_081457.txt
# 0 data/test/180715_174958.txt
# 0 data/test/180715_082514.txt
# 0 data/test/180714_134927.txt
# 8 data/test/180713_123709.txt
# 0 data/test/180718_140103.txt
# 0 data/test/180717_113713.txt
# 0 data/test/180718_102533.txt
# 0 data/test/180717_082658.txt
# 0 data/test/180718_200125.txt
# 0 data/test/180717_095118.txt
# 1 data/test/180713_163804.txt
# 0 data/test/180713_175152.txt
# 0 data/test/180715_152539.txt
# 0 data/test/180712_122710.txt
# 0 data/test/180713_140208.txt
# 0 data/test/180714_110202.txt
# 0 data/test/180716_155122.txt
# 0 data/test/180718_071327.txt
# 0 data/test/180716_112503.txt
# 0 data/test/180713_082801.txt
# 7 data/test/180716_064913.txt
# 0 data/test/180716_122839.txt
# 0 data/test/180718_091546.txt
# 0 data/test/180713_114919.txt
# 0 data/test/180717_080209.txt
# 0 data/test/180713_120308.txt
# 0 data/test/180714_151506.txt
# 7 data/test/180714_132514.txt
# 1 data/test/180717_171308.txt
# 0 data/test/180717_172718.txt
# 0 data/test/180718_140109.txt
# 0 data/test/180712_062543.txt
# 0 data/test/180716_071606.txt
# 0 data/test/180715_102732.txt
# 0 data/test/180718_181314.txt
# 0 data/test/180713_175109.txt
# 0 data/test/180712_061506.txt
# 0 data/test/180717_093725.txt
# 0 data/test/180716_073939.txt
# 6 data/test/180713_180352.txt
# 0 data/test/180714_171324.txt
# 0 data/test/180717_173817.txt
# 0 data/test/180717_112515.txt
# 0 data/test/180716_171513.txt
# 0 data/test/180716_091509.txt
# 0 data/test/180717_145053.txt
# 0 data/test/180717_113913.txt
# 0 data/test/180715_084921.txt
# 0 data/test/180715_120143.txt
# 0 data/test/180715_122656.txt
# 0 data/test/180714_110338.txt
# 0 data/test/180718_171404.txt
# 0 data/test/180717_151315.txt
# 8 data/test/180713_163811.txt
# 0 data/test/180715_122558.txt
# 0 data/test/180718_172503.txt
# 0 data/test/180717_153947.txt
# 0 data/test/180716_183803.txt
# 0 data/test/180712_080115.txt
# 1 data/test/180715_122736.txt
# 0 data/test/180716_061546.txt
# 0 data/test/180717_105116.txt
# 0 data/test/180714_130134.txt
# 0 data/test/180718_172808.txt

# %%
im = images[7]

# %%
im
# Out:
# 'data/test/180716_182526.JPG'

# %%
# run your custom detector on image 
# !./darknet detector test data/obj.data cfg/yolov4-tiny.cfg /mydrive/YOLO/backup/yolov4-tiny_2700.weights data/test/180716_190328.JPG -Threshold 
imShow('predictions.jpg')

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# # Cheers!
